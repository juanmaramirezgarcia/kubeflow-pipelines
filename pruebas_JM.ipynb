# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np

# %%
import pandas as pd
from sklearn.datasets import fetch_openml
housing = fetch_openml(name="house_prices", as_frame=True)

# %%
housing['data']
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave  None      Reg
# 1        2.0        20.0       RL         80.0   9600.0   Pave  None      Reg
# 2        3.0        60.0       RL         68.0  11250.0   Pave  None      IR1
# 3        4.0        70.0       RL         60.0   9550.0   Pave  None      IR1
# 4        5.0        60.0       RL         84.0  14260.0   Pave  None      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456.0        60.0       RL         62.0   7917.0   Pave  None      Reg
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave  None      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave  None      Reg
# 1458  1459.0        20.0       RL         68.0   9717.0   Pave  None      Reg
# 1459  1460.0        20.0       RL         75.0   9937.0   Pave  None      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         0.0      0.0   None   None
# 1            Lvl    AllPub  ...         0.0      0.0   None   None
# 2            Lvl    AllPub  ...         0.0      0.0   None   None
# 3            Lvl    AllPub  ...         0.0      0.0   None   None
# 4            Lvl    AllPub  ...         0.0      0.0   None   None
# ...          ...       ...  ...         ...      ...    ...    ...
# 1455         Lvl    AllPub  ...         0.0      0.0   None   None
# 1456         Lvl    AllPub  ...         0.0      0.0   None  MnPrv
# 1457         Lvl    AllPub  ...         0.0      0.0   None  GdPrv
# 1458         Lvl    AllPub  ...         0.0      0.0   None   None
# 1459         Lvl    AllPub  ...         0.0      0.0   None   None
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0           None     0.0    2.0  2008.0        WD         Normal
# 1           None     0.0    5.0  2007.0        WD         Normal
# 2           None     0.0    9.0  2008.0        WD         Normal
# 3           None     0.0    2.0  2006.0        WD        Abnorml
# 4           None     0.0   12.0  2008.0        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1455        None     0.0    8.0  2007.0        WD         Normal
# 1456        None     0.0    2.0  2010.0        WD         Normal
# 1457        Shed  2500.0    5.0  2010.0        WD         Normal
# 1458        None     0.0    4.0  2010.0        WD         Normal
# 1459        None     0.0    6.0  2008.0        WD         Normal
#
# [1460 rows x 80 columns]

# %%
boston = datasets.load_boston()
X, y = boston.data, boston.target
# Out:
# c:\Users\029492838\AppData\Local\miniconda3\envs\py37kubeflow\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.preprocessing import scale

X = scale(X)
y = scale(y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
import joblib
from sklearn.linear_model import SGDRegressor

model = SGDRegressor(alpha=0.0001, epsilon=0.01, eta0=0.1,penalty='elasticnet',verbose=1)
model.fit(X_train, y_train)
   
joblib.dump(model, 'model.pkl')
# Out:
# -- Epoch 1
# Norm: 0.82, NNZs: 13, Bias: -0.002679, T: 430, Avg. loss: 0.222769
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 0.80, NNZs: 13, Bias: -0.002281, T: 860, Avg. loss: 0.179475
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 0.88, NNZs: 13, Bias: 0.008917, T: 1290, Avg. loss: 0.165703
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 0.91, NNZs: 13, Bias: 0.040849, T: 1720, Avg. loss: 0.157795
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 0.78, NNZs: 13, Bias: 0.039410, T: 2150, Avg. loss: 0.165181
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 0.80, NNZs: 13, Bias: -0.041407, T: 2580, Avg. loss: 0.154197
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 0.79, NNZs: 13, Bias: -0.004066, T: 3010, Avg. loss: 0.161552
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 0.77, NNZs: 13, Bias: -0.013929, T: 3440, Avg. loss: 0.160436
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 0.88, NNZs: 13, Bias: 0.008241, T: 3870, Avg. loss: 0.156509
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 0.85, NNZs: 13, Bias: 0.019639, T: 4300, Avg. loss: 0.152215
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 0.82, NNZs: 12, Bias: -0.030180, T: 4730, Avg. loss: 0.155483
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 0.77, NNZs: 13, Bias: 0.008847, T: 5160, Avg. loss: 0.152656
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 0.80, NNZs: 13, Bias: 0.011186, T: 5590, Avg. loss: 0.152351
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 0.87, NNZs: 13, Bias: 0.001226, T: 6020, Avg. loss: 0.149197
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 0.88, NNZs: 12, Bias: 0.026035, T: 6450, Avg. loss: 0.155359
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 0.84, NNZs: 13, Bias: 0.021034, T: 6880, Avg. loss: 0.155720
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 0.81, NNZs: 13, Bias: 0.014779, T: 7310, Avg. loss: 0.147561
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 0.85, NNZs: 12, Bias: 0.036337, T: 7740, Avg. loss: 0.153153
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 0.75, NNZs: 13, Bias: 0.017151, T: 8170, Avg. loss: 0.151325
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 0.84, NNZs: 13, Bias: -0.038056, T: 8600, Avg. loss: 0.154127
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 0.85, NNZs: 13, Bias: 0.033102, T: 9030, Avg. loss: 0.150551
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 0.85, NNZs: 12, Bias: -0.004192, T: 9460, Avg. loss: 0.151968
# Total training time: 0.00 seconds.
# Convergence after 22 epochs took 0.00 seconds
# ['model.pkl']

# %%
from sklearn.metrics import mean_squared_error

model = joblib.load('model.pkl')
y_pred = model.predict(X_test)

err = mean_squared_error(y_test, y_pred)

# %%
print(err)
# Out:
# 0.251321455339241
